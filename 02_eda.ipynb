# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [<b>Load Dataset</b>](#toc1_)
#     - [Load Config Data](#toc1_1_1_)
#     - [Load Dataset](#toc1_1_2_)
# - [<b> Exploratory Data Analysis</b>](#toc2_)
#   - [Profile Report](#toc2_1_)
#   - [Describe Data](#toc2_2_)
#   - [<b> 1. Histogram</b>](#toc2_3_)
#   - [<b>2. Kernel Density Plot</b>](#toc2_4_)
#   - [<b>3. Boxplot of Numeric features</b>](#toc2_5_)
#   - [<b>4.Segment Categorical features by the target classes</b>](#toc2_6_)
#   - [<b>5. Barplot of Categoric Features</b>](#toc2_7_)
#   - [<b>6. Group numeric features by categorical features</b>](#toc2_8_)
#   - [<b>7. Heatmap Correlation</b>](#toc2_9_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %%
## Load Configuration File

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import src.util as util
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler, SMOTENC
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LassoCV
from xgboost import XGBClassifier

import warnings

warnings.filterwarnings('ignore')

# %%
import klib
from ydata_profiling import ProfileReport, compare

# %%
sns.set_style('darkgrid')
sns.set(rc = {'axes.facecolor': '#FBFBFB', 'figure.facecolor': '#FBFBFB'})

class clr:
    start = '\033[93m'+'\033[1m'
    bold = '\033[1m'
    underline = '\033[4m'
    color = '\033[93m'
    end = '\033[0m'

# %% [markdown]
# # <a id='toc1_'></a>[<b>Load Dataset</b>](#toc0_)

# %%
def load_dataset(config_data: dict) -> pd.DataFrame:
    # Load set of data
    x_train = util.pickle_load(config_data["train_set_path"][0])
    y_train = util.pickle_load(config_data["train_set_path"][1])

    x_valid = util.pickle_load(config_data["valid_set_path"][0])
    y_valid = util.pickle_load(config_data["valid_set_path"][1])

    x_test = util.pickle_load(config_data["test_set_path"][0])
    y_test = util.pickle_load(config_data["test_set_path"][1])

    # concatenate x and y each set
    train_set = pd.concat([x_train, y_train], axis = 1)
    valid_set = pd.concat([x_valid, y_valid], axis = 1)
    test_set = pd.concat([x_test, y_test], axis = 1)

    # return 3 set of data
    return train_set, valid_set, test_set

# %% [markdown]
# ### <a id='toc1_1_1_'></a>[Load Config Data](#toc0_)

# %%
config_data = util.load_config()

# %% [markdown]
# ### <a id='toc1_1_2_'></a>[Load Dataset](#toc0_)

# %%
train_set, valid_set, test_set = load_dataset(config_data)

# %% [markdown]
# # <a id='toc2_'></a>[<b> Exploratory Data Analysis</b>](#toc0_)

# %% [markdown]
# -----

# %% [markdown]
# ## <a id='toc2_1_'></a>[Profile Report](#toc0_)

# %%
train_set_report = ProfileReport(train_set, progress_bar=False, title="train_set", explorative=True, sample=None)

train_set_report.to_file("data_profile_report.html")

# %% [markdown]
# ## <a id='toc2_2_'></a>[Describe Data](#toc0_)

# %%
train_set.describe().style.background_gradient(cmap='YlOrBr')
# Out:
# <style type="text/css">
# #T_69da4_row0_col0, #T_69da4_row0_col1, #T_69da4_row0_col7, #T_69da4_row2_col6, #T_69da4_row7_col2, #T_69da4_row7_col3, #T_69da4_row7_col4, #T_69da4_row7_col5, #T_69da4_row7_col8, #T_69da4_row7_col9, #T_69da4_row7_col10, #T_69da4_row7_col11 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_69da4_row0_col2, #T_69da4_row0_col4, #T_69da4_row0_col8, #T_69da4_row0_col11, #T_69da4_row2_col1, #T_69da4_row2_col3, #T_69da4_row3_col0, #T_69da4_row3_col5, #T_69da4_row3_col6, #T_69da4_row3_col7, #T_69da4_row3_col9, #T_69da4_row3_col10, #T_69da4_row4_col5, #T_69da4_row5_col5 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_69da4_row0_col3, #T_69da4_row1_col10, #T_69da4_row5_col9 {
#   background-color: #fed471;
#   color: #000000;
# }
# #T_69da4_row0_col5, #T_69da4_row2_col7, #T_69da4_row3_col8, #T_69da4_row3_col11 {
#   background-color: #fffee2;
#   color: #000000;
# }
# #T_69da4_row0_col6 {
#   background-color: #b44103;
#   color: #f1f1f1;
# }
# #T_69da4_row0_col9, #T_69da4_row1_col1, #T_69da4_row5_col1 {
#   background-color: #fffdd9;
#   color: #000000;
# }
# #T_69da4_row0_col10 {
#   background-color: #fffddb;
#   color: #000000;
# }
# #T_69da4_row1_col0, #T_69da4_row2_col2 {
#   background-color: #fee28e;
#   color: #000000;
# }
# #T_69da4_row1_col2 {
#   background-color: #f88a21;
#   color: #f1f1f1;
# }
# #T_69da4_row1_col3 {
#   background-color: #f5841e;
#   color: #f1f1f1;
# }
# #T_69da4_row1_col4 {
#   background-color: #b34003;
#   color: #f1f1f1;
# }
# #T_69da4_row1_col5 {
#   background-color: #fee493;
#   color: #000000;
# }
# #T_69da4_row1_col6 {
#   background-color: #ee7617;
#   color: #f1f1f1;
# }
# #T_69da4_row1_col7, #T_69da4_row3_col1, #T_69da4_row5_col7 {
#   background-color: #fffee1;
#   color: #000000;
# }
# #T_69da4_row1_col8 {
#   background-color: #feaa38;
#   color: #000000;
# }
# #T_69da4_row1_col9, #T_69da4_row6_col0 {
#   background-color: #fecb5f;
#   color: #000000;
# }
# #T_69da4_row1_col11 {
#   background-color: #fea433;
#   color: #000000;
# }
# #T_69da4_row2_col0 {
#   background-color: #fff4b6;
#   color: #000000;
# }
# #T_69da4_row2_col4 {
#   background-color: #fff8c0;
#   color: #000000;
# }
# #T_69da4_row2_col5 {
#   background-color: #fedd84;
#   color: #000000;
# }
# #T_69da4_row2_col8 {
#   background-color: #fee799;
#   color: #000000;
# }
# #T_69da4_row2_col9 {
#   background-color: #fee697;
#   color: #000000;
# }
# #T_69da4_row2_col10 {
#   background-color: #feeaa1;
#   color: #000000;
# }
# #T_69da4_row2_col11 {
#   background-color: #fee596;
#   color: #000000;
# }
# #T_69da4_row3_col2 {
#   background-color: #fff9c5;
#   color: #000000;
# }
# #T_69da4_row3_col3 {
#   background-color: #fff8c2;
#   color: #000000;
# }
# #T_69da4_row3_col4 {
#   background-color: #da5c0a;
#   color: #f1f1f1;
# }
# #T_69da4_row4_col0 {
#   background-color: #fff4b5;
#   color: #000000;
# }
# #T_69da4_row4_col1, #T_69da4_row7_col7 {
#   background-color: #fffddc;
#   color: #000000;
# }
# #T_69da4_row4_col2 {
#   background-color: #fecf67;
#   color: #000000;
# }
# #T_69da4_row4_col3 {
#   background-color: #fea231;
#   color: #000000;
# }
# #T_69da4_row4_col4 {
#   background-color: #d35406;
#   color: #f1f1f1;
# }
# #T_69da4_row4_col6 {
#   background-color: #feb13e;
#   color: #000000;
# }
# #T_69da4_row4_col7 {
#   background-color: #ffffe4;
#   color: #000000;
# }
# #T_69da4_row4_col8 {
#   background-color: #fecc61;
#   color: #000000;
# }
# #T_69da4_row4_col9 {
#   background-color: #feeda6;
#   color: #000000;
# }
# #T_69da4_row4_col10 {
#   background-color: #ffeea9;
#   color: #000000;
# }
# #T_69da4_row4_col11 {
#   background-color: #fec859;
#   color: #000000;
# }
# #T_69da4_row5_col0 {
#   background-color: #fee390;
#   color: #000000;
# }
# #T_69da4_row5_col2 {
#   background-color: #f98e23;
#   color: #f1f1f1;
# }
# #T_69da4_row5_col3 {
#   background-color: #f4821d;
#   color: #f1f1f1;
# }
# #T_69da4_row5_col4 {
#   background-color: #cb4b02;
#   color: #f1f1f1;
# }
# #T_69da4_row5_col6, #T_69da4_row6_col3 {
#   background-color: #e66a11;
#   color: #f1f1f1;
# }
# #T_69da4_row5_col8 {
#   background-color: #fe9a2a;
#   color: #000000;
# }
# #T_69da4_row5_col10 {
#   background-color: #fedb80;
#   color: #000000;
# }
# #T_69da4_row5_col11 {
#   background-color: #fb9225;
#   color: #000000;
# }
# #T_69da4_row6_col1 {
#   background-color: #fffcd7;
#   color: #000000;
# }
# #T_69da4_row6_col2 {
#   background-color: #c84a02;
#   color: #f1f1f1;
# }
# #T_69da4_row6_col4 {
#   background-color: #712806;
#   color: #f1f1f1;
# }
# #T_69da4_row6_col5 {
#   background-color: #fe9829;
#   color: #000000;
# }
# #T_69da4_row6_col6, #T_69da4_row7_col6 {
#   background-color: #b84203;
#   color: #f1f1f1;
# }
# #T_69da4_row6_col7 {
#   background-color: #fffedf;
#   color: #000000;
# }
# #T_69da4_row6_col8 {
#   background-color: #ee7416;
#   color: #f1f1f1;
# }
# #T_69da4_row6_col9 {
#   background-color: #fa8f24;
#   color: #f1f1f1;
# }
# #T_69da4_row6_col10 {
#   background-color: #fea634;
#   color: #000000;
# }
# #T_69da4_row6_col11 {
#   background-color: #e96d13;
#   color: #f1f1f1;
# }
# #T_69da4_row7_col0 {
#   background-color: #f07818;
#   color: #f1f1f1;
# }
# #T_69da4_row7_col1 {
#   background-color: #fffbcf;
#   color: #000000;
# }
# </style>
# <table id="T_69da4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_69da4_level0_col0" class="col_heading level0 col0" >months_as_customer</th>
#       <th id="T_69da4_level0_col1" class="col_heading level0 col1" >age</th>
#       <th id="T_69da4_level0_col2" class="col_heading level0 col2" >policy_number</th>
#       <th id="T_69da4_level0_col3" class="col_heading level0 col3" >policy_annual_premium</th>
#       <th id="T_69da4_level0_col4" class="col_heading level0 col4" >insured_zip</th>
#       <th id="T_69da4_level0_col5" class="col_heading level0 col5" >capital_gains</th>
#       <th id="T_69da4_level0_col6" class="col_heading level0 col6" >capital_loss</th>
#       <th id="T_69da4_level0_col7" class="col_heading level0 col7" >incident_hour_of_the_day</th>
#       <th id="T_69da4_level0_col8" class="col_heading level0 col8" >total_claim_amount</th>
#       <th id="T_69da4_level0_col9" class="col_heading level0 col9" >injury_claim</th>
#       <th id="T_69da4_level0_col10" class="col_heading level0 col10" >property_claim</th>
#       <th id="T_69da4_level0_col11" class="col_heading level0 col11" >vehicle_claim</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69da4_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_69da4_row0_col0" class="data row0 col0" >800.000000</td>
#       <td id="T_69da4_row0_col1" class="data row0 col1" >800.000000</td>
#       <td id="T_69da4_row0_col2" class="data row0 col2" >800.000000</td>
#       <td id="T_69da4_row0_col3" class="data row0 col3" >800.000000</td>
#       <td id="T_69da4_row0_col4" class="data row0 col4" >800.000000</td>
#       <td id="T_69da4_row0_col5" class="data row0 col5" >800.000000</td>
#       <td id="T_69da4_row0_col6" class="data row0 col6" >800.000000</td>
#       <td id="T_69da4_row0_col7" class="data row0 col7" >800.000000</td>
#       <td id="T_69da4_row0_col8" class="data row0 col8" >800.000000</td>
#       <td id="T_69da4_row0_col9" class="data row0 col9" >800.000000</td>
#       <td id="T_69da4_row0_col10" class="data row0 col10" >800.000000</td>
#       <td id="T_69da4_row0_col11" class="data row0 col11" >800.000000</td>
#     </tr>
#     <tr>
#       <th id="T_69da4_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_69da4_row1_col0" class="data row1 col0" >204.001250</td>
#       <td id="T_69da4_row1_col1" class="data row1 col1" >39.016250</td>
#       <td id="T_69da4_row1_col2" class="data row1 col2" >544664.695000</td>
#       <td id="T_69da4_row1_col3" class="data row1 col3" >1257.717500</td>
#       <td id="T_69da4_row1_col4" class="data row1 col4" >502376.073750</td>
#       <td id="T_69da4_row1_col5" class="data row1 col5" >24541.625000</td>
#       <td id="T_69da4_row1_col6" class="data row1 col6" >-26499.875000</td>
#       <td id="T_69da4_row1_col7" class="data row1 col7" >11.568750</td>
#       <td id="T_69da4_row1_col8" class="data row1 col8" >52173.800000</td>
#       <td id="T_69da4_row1_col9" class="data row1 col9" >7373.562500</td>
#       <td id="T_69da4_row1_col10" class="data row1 col10" >7324.225000</td>
#       <td id="T_69da4_row1_col11" class="data row1 col11" >37476.012

# %%
train_set.describe(include='object')
# Out:
#        policy_deductable umbrella_limit number_of_vehicles_involved  \
# count                800            800                         800
# unique                 3             11                           4
# top                  500              0                           1
# freq                 277            639                         466
#
#        bodily_injuries witnesses auto_year policy_state policy_csl  \
# count              800       800       800          800        800
# unique               3         4        21            3          3
# top                  0         1      2003           OH    250/500
# freq               276       208        48          282        286
#
#        insured_sex insured_hobbies  ...  collision_type incident_severity  \
# count          800             800  ...             800               800
# unique           2              20  ...               4                 4
# top         FEMALE         reading  ...  Rear Collision      Minor Damage
# freq           426              54  ...             232               281
#
#        authorities_contacted incident_state incident_city property_damage  \
# count                    800            800           800             800
# unique                     5              7             7               3
# top                   Police             NY   Springfield         UNKNOWN
# freq                     235            205           127             286
#
#        police_report_available auto_make auto_model fraud_reported
# count                      800       800        800            800
# unique                       3        14         39              2
# top                         NO    Suburu   Wrangler              N
# freq                       278        70         33            602
#
# [4 rows x 21 columns]

# %% [markdown]
# ## <a id='toc2_3_'></a>[<b> 1. Histogram</b>](#toc0_)

# %% [markdown]
# What we look out for:
# - Potential <b>outliers</b>
# - <b>Numeric features that should be categorical (indicator)</b> features. For example, if there are only two possible values like 0 and 1.
# - Boundaries that do not make sense, such as <b>percentage value more than 100</b>.
#
# Using the `histplot` from seaborn with `kind = kde`, and separate the histogram into two category of target. <br>
# Histogram are using to approach the miscellaneous thing we seek before, while `kde` are using to understand the distribution of the numeric features.

# %%
list_num_col = []

for col in train_set.columns:
    if (train_set[col].dtype =='int32'):
        list_num_col.append(col)

plt.figure(figsize=(10,10))
count = 0

for i in range(len(list_num_col) // 2):
    for j in range(2):

        if count >= len(list_num_col):
            break

        g = sns.FacetGrid(data=train_set, col='fraud_reported', hue='fraud_reported', height=4, aspect= 2)
        g.map_dataframe(sns.histplot, x=list_num_col[count])
        g.map_dataframe(sns.kdeplot, x=list_num_col[count])
        
        g.refline(x=train_set[list_num_col[count]].mean(), color='r')
        g.refline(x=train_set[list_num_col[count]].median(), linestyle='-')

        plt.legend(['mean', 'median'])

        count += 1

plt.tight_layout()
plt.show()

# %% [markdown]
# - <b>`insured_zip`</b> are prone into two group of <b>>500.000</b> and <b><600.000</b>
# - <b>`capital_gains`</b> is highly <b>left-skewed</b> distributed since it has much zero values (0)

# %% [markdown]
# ## <a id='toc2_4_'></a>[<b>2. Kernel Density Plot</b>](#toc0_)

# %% [markdown]
# KDE plot using `klib.dist_plot` to give better distribution comprehension of numeric features, given <b>mean, median, and standard deviation</b>

# %%
klib.dist_plot(train_set)
# Out:
# <Axes: xlabel='vehicle_claim', ylabel='Density'>

# %% [markdown]
# There are several features in the dataset that exhibit a **`bimodal distribution`**, meaning they have two distinct peaks or modes. These features are strongly **correlated with the amount of money**. Consequently, the **occurrence of a value of 0 in these features creates the bimodal distribution**. The correlation with the amount of money suggests that these features play a significant role in determining the monetary values observed in the dataset.

# %% [markdown]
# ## <a id='toc2_5_'></a>[<b>3. Boxplot of Numeric features</b>](#toc0_)

# %% [markdown]
# **Segment the target by numeric features**
#
# <center>
# <img src='https://th.bing.com/th/id/OIP.0MPDTLn8KoLApoFvI0P2vQHaDt?pid=ImgDet&rs=1'>
# </center>
#
# We will use **`sns.boxplot`** which displays the five-number summary of a numeric feature. The five numbers are **minimum**, **first quartile (Q1 or 25% mark)**,**median (Q2)**, **third quartile (Q3 or 75% mark)**, and **maximum**
#
# Here, we will separate the data by the target feature and observe how the numeric features are distributed among those which **fraud (target = 1)** and those which **non-fraud (target = 0)**.

# %%
fig, axs = plt.subplots(len(list_num_col) // 2, 2, figsize=(12,15))
count = 0

train_set_box = train_set.copy()
train_set_box.fraud_reported = train_set_box.fraud_reported.map(dict(Y=1,N=0))


for i in range(len(list_num_col) // 2):
    for j in range(2):

        if count >= len(list_num_col):
            break

        sns.boxplot(data = train_set_box, x=list_num_col[count], y='fraud_reported', ax=axs[i, j], orient='h')

        axs[i, j].tick_params(axis='x', labelsize=8)
        axs[i, j].tick_params(axis='y', labelsize=8)

        axs[i, j].set_xlabel('')
        axs[i, j].set_ylabel('')
        axs[i, j].set_title(list_num_col[count], fontweight='bold')
        # axs[i, j].legend(loc='upper right')

        count += 1

# fig.legend(['N','Y'], loc='upper right', title='fraud_reported')

plt.tight_layout()
plt.show()

# %% [markdown]
# We can see that **`month_as_customers, age, insured_zip, capital_gains, capital_loss, incident_hours_of_the_day`** <br>
# are almost **equally distributed** among those which non-fraud (target 0) and those which fraud (target 1). <br>
# This means that training_hours **might not be a good predictor** for the target.
#
# However, we see that when it comes to **`policy_annual_premium, total_claim_amount, injury_claim, property_claim, vehicle_claim`**,<br>
# a bigger proportion of those who stayed are tending towards more years of experience and these could be **good predictors**.

# %% [markdown]
# ## <a id='toc2_6_'></a>[<b>4.Segment Categorical features by the target classes</b>](#toc0_)

# %% [markdown]
# Now that we have seen how the target changes with numeric features, we will do the same for categorical features.
#
# **`pd.crosstab(col1, col2)`** function builds a *cross-tabulation table* that shows the **relationship between two categorical features**. The table shows the **frequency** by which groups of data from the two features appear. You can include the parameter `normalize='index'` to show the percentages
#
# Here, loop through 4 categorical columns (those with less than 5 unique classes).

# %%
list_cat_col = []

for col in train_set.columns:
    if (train_set[col].dtype =='object'):
        list_cat_col.append(col)
for col in list_cat_col:
    if train_set[col].nunique() <= 4:
        display(pd.crosstab(train_set.fraud_reported, train_set[col], normalize='index').style.background_gradient(cmap='YlOrBr'))
# Out:
# <style type="text/css">
# #T_7226b_row0_col0, #T_7226b_row1_col1, #T_7226b_row1_col2 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_7226b_row0_col1, #T_7226b_row0_col2, #T_7226b_row1_col0 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# </style>
# <table id="T_7226b">
#   <thead>
#     <tr>
#       <th class="index_name level0" >policy_deductable</th>
#       <th id="T_7226b_level0_col0" class="col_heading level0 col0" >1000</th>
#       <th id="T_7226b_level0_col1" class="col_heading level0 col1" >2000</th>
#       <th id="T_7226b_level0_col2" class="col_heading level0 col2" >500</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >fraud_reported</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7226b_level0_row0" class="row_heading level0 row0" >N</th>
#       <td id="T_7226b_row0_col0" class="data row0 col0" >0.342193</td>
#       <td id="T_7226b_row0_col1" class="data row0 col1" >0.312292</td>
#       <td id="T_7226b_row0_col2" class="data row0 col2" >0.345515</td>
#     </tr>
#     <tr>
#       <th id="T_7226b_level0_row1" class="row_heading level0 row1" >Y</th>
#       <td id="T_7226b_row1_col0" class="data row1 col0" >0.313131</td>
#       <td id="T_7226b_row1_col1" class="data row1 col1" >0.338384</td>
#       <td id="T_7226b_row1_col2" class="data row1 col2" >0.348485</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_91041_row0_col0, #T_91041_row1_col1, #T_91041_row1_col2, #T_91041_row1_col3 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_91041_row0_col1, #T_91041_row0_col2, #T_91041_row0_col3, #T_91041_row1_col0 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# </style>
# <table id="T_91041">
#   <thead>
#     <tr>
#       <th class="index_name level0" >number_of_vehicles_involved</th>
#       <th id="T_91041_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_91041_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_91041_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_91041_level0_col3" class="col_heading level0 col3" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >fraud_reported</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_91041_level0_row0" class="row_heading level0 row0" >N</th>
#       <td id="T_91041_row0_col0" class="data row0 col0" >0.594684</td>
#       <td id="T_91041_row0_col1" class="data row0 col1" >0.026578</td>
#       <td id="T_91041_row0_col2" class="data row0 col2" >0.350498</td>
#       <td id="T_91041_row0_col3" class="data row0 col3" >0.028239</td>
#     </tr>
#     <tr>
#       <th id="T_91041_level0_row1" class="row_heading level0 row1" >Y</th>
#       <td id="T_91041_row1_col0" class="data row1 col0" >0.545455</td>
#       <td id="T_91041_row1_col1" class="data row1 col1" >0.035354</td>
#       <td id="T_91041_row1_col2" class="data row1 col2" >0.378788</td>
#       <td id="T_91041_row1_col3" class="data row1 col3" >0.040404</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_39b66_row0_col0, #T_39b66_row0_col1, #T_39b66_row1_col2 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_39b66_row0_col2, #T_39b66_row1_col0, #T_39b66_row1_col1 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# </style>
# <table id="T_39b66">
#   <thead>
#     <tr>
#       <th class="index_name level0" >bodily_injuries</th>
#       <th id="T_39b66_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_39b66_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_39b66_level0_col2" class="col_heading level0 col2" >2</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >fraud_reported</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_39b66_level0_row0" class="row_heading level0 row0" >N</th>
#       <td id="T_39b66_row0_col0" class="data row0 col0" >0.353821</td>
#       <td id="T_39b66_row0_col1" class="data row0 col1" >0.323920</td>
#       <td id="T_39b66_row0_col2" class="data row0 col2" >0.322259</td>
#     </tr>
#     <tr>
#       <th id="T_39b66_level0_row1" class="row_heading level0 row1" >Y</th>
#       <td id="T_39b66_row1_col0" class="data row1 col0" >0.318182</td>
#       <td id="T_39b66_row1_col1" class="data row1 col1" >0.287879</td>
#       <td id="T_39b66_row1_col2" class="data row1 col2" >0.393939</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_3018d_row0_col0, #T_3018d_row0_col1, #T_3018d_row1_col2, #T_3018d_row1_col3 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_3018d_row0_col2, #T_3018d_row0_col3, #T_3018d_row1_col0, #T_3018d_row1_col1 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# </style>
# <table id="T_3018d">
#   <thead>
#     <tr>
#       <th class="index_name level0" >witnesses</th>
#       <th id="T_3018d_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_3018d_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_3018d_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_3018d_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >fraud_reported</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3018d_level0_row0" class="row_heading level0 row0" >N</th>
#       <td id="T_3018d_row0_col0" class="data row0 col0" >0.262458</td>
#       <td id="T_3018d_row0_col1" class="data row0 col1" >0.260797</td>
#       <td id="T_3018d_row0_col2" class="data row0 col2" >0.237542</td>
#       <td id="T_3018d_row0_col3" class="data row0 col3" >0.239203</td>
#     </tr>
#     <tr>
#       <th id="T_3018d_level0_row1" class="row_heading level0 row1" >Y</th>
#       <td id="T_3018d_row1_col0" class="data row1 col0" >0.191919</td>
#       <td id="T_3018d_row1_col1" class="data row1 col1" >0.257576</td>
#       <td id="T_3018d_row1_col2" class="data row1 col2" >0.308081</td>
#       <td id="T_3018d_row1_col3" class="data row1 col3" >0.242424</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_26824_row0_col0, #T_26824_row0_col1, #T_26824_row1_col2 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_26824_row0_col2, #T_26824_row1_col0, #T_26824_row1_col1 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# </style>
# <table id="T_26824">
#   <thead>
#     <tr>
#       <th class="index_name level0" >policy_state</th>
#       <th id="T_26824_level0_col0" class="col_heading level0 col0" >IL</th>
#       <th id="T_26824_level0_col1" class="col_heading level0 col1" >IN</th>
#       <th id="T_26824_level0_col2" class="col_heading level0 col2" >OH</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >fraud_reported</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26824_level0_row0" class="row_heading level0 row0" >N</th>
#       <td id="T_26824_row0_col0" class="data row0 col0" >0.335548</td>
#       <td id="T_26824_row0_col1" class="data row0 col1" >0.317276</td>
#       <td id="T_26824_row0_col2" class="data row0 col2" >0.347176</td>
#     </tr>
#     <tr>
#       <th id="T_26824_level0_row1" class="row_heading level0 row1" >Y</th>
#       <td id="T_26824_row1_col0" class="data row1 col0" >0.318182</td>
#       <td id="T_26824_row1_col1" class="data row1 col1" >0.313131</td>
#       <td id="T_26824_row1_col2" class="data row1 col2" >0.368687</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_fdfe7_row0_col0, #T_fdfe7_row1_col1, #T_fdfe7_row1_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_fdfe7_row0_col1, #T_fdfe7_row0_col2, #T_fdfe7_row1_col0 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_fdfe7">
#   <thead>
#     <tr>
#       <th class="index_name level0" >policy_csl</th>
#       <th id="T_fdfe7_level0_col0" class="col_heading level0 col0" >100/300</th>
#       <th id="T_fdfe7_level0_col1" class="col_heading level0 col1" >250/500</th>
#       <th id="T_fdfe7_level0_col2" class="col_heading level0 col2" >500/1000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >fraud_reported</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fdfe7_level0_row0" class="row_heading level0 row0" >N</th>
#       <td id="T_fdfe7_row0_col0" class="data row0 col0" >0.335548</td>
#       <td id="T_fdfe7_row0_col1" class="data row0 col1" >0.358804</td>
#       <td id="T_fdfe7_row0_col2" class="data row0 col2" >0.305648</td>
#     </tr>
#     <tr>
#       <th id="T_fdfe7_level0_row1" class="row_heading level0 row1" >Y</th>
#       <td id="T_fdfe7_row1_col0" class="data row1 col0" >0.363636</td>
#       <td id="T_fdfe7_row1_col1" class="data row1 col1" >0.353535</td>
#       <td id="T_fdfe7_row1_col2" class="data row1 col2" >0.282828</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_90704_row0_col0, #T_90704_row1_col1 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_90704_row0_col1, #T_90704_row1_col0 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# </style>
# <table id="T_90704">
#   <thead>
#     <tr>
#       <th class="index_name level0" >insured_sex</th>
#       <th id="T_90704_level0_col0" class="col_heading level0 col0" >FEMALE</th>
#       <th id="T_90704_level0_col1" class="col_heading level0 col1" >MALE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >fraud_reported</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90704_level0_row0" class="row_heading level0 row0" >N</th>
#       <td id="T_90704_row0_col0" class="data row0 col0" >0.533223</td>
#       <td id="T_90704_row0_col1" class="data row0 col1" >0.466777</td>
#     </tr>
#     <tr>
#       <th id="T_90704_level0_row1" class="row_heading level0 row1" >Y</th>
#       <td id="T_90704_row1_col0" class="data row1 col0" >0.530303</td>
#       <td id="T_90704_row1_col1" class="data row1 col1" >0.469697</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_dcd3b_row0_col0, #T_dcd3b_row0_col2, #T_dcd3b_row1_col1, #T_dcd3b_row1_col3 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_dcd3b_row0_col1, #T_dcd3b_row0_col3, #T_dcd3b_row1_col0, #T_dcd3b_row1_col2 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_dcd3b">
#   <thead>
#     <tr>
#       <th class="index_name level0" >incident_type</th>
#       <th id="T_dcd3b_level0_col0" class="col_heading level0 col0" >Multi-vehicle Collision</th>
#       <th id="T_dcd3b_level0_col1" class="col_heading level0 col1" >Parked Car</th>
#       <th id="T_dcd3b_level0_col2" class="col_heading level0 col2" >Single Vehicle Collision</th>
#       <th id="T_dcd3b_level0_col3" class="col_heading level0 col3" >Vehicle Theft</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >fraud_reported</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dcd3b_level0_row0" class="row_heading level0 row0" >N</th>
#       <td id="T_dcd3b_row0_col0" class="data row0 col0" >0.405316</td>
#       <td id="T_dcd3b_row0_col1" class="data row0 col1" >0.114618</td>
#       <td id="T_dcd3b_row0_col2" class="data row0 col2" >0.367110</td>
#       <td id="T_dcd3b_row0_col3" class="data row0 col3" >0.112957</td>
#     </tr>
#     <tr>
#       <th id="T_dcd3b_level0_row1" class="row_heading level0 row1" >Y</th>
#       <td id="T_dcd3b_row1_col0" class="data row1 col0" >0.454545</td>
#       <td id="T_dcd3b_row1_col1" class="data row1 col1" >0.040404</td>
#       <td id="T_dcd3b_row1_col2" class="data row1 col2" >0.469697</td>
#       <td id="T_dcd3b_row1_col3" class="data row1 col3" >0.035354</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_a5f86_row0_col0, #T_a5f86_row0_col1, #T_a5f86_row0_col2, #T_a5f86_row1_col3 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_a5f86_row0_col3, #T_a5f86_row1_col0, #T_a5f86_row1_col1, #T_a5f86_row1_col2 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a5f86">
#   <thead>
#     <tr>
#       <th class="index_name level0" >collision_type</th>
#       <th id="T_a5f86_level0_col0" class="col_heading level0 col0" >Front Collision</th>
#       <th id="T_a5f86_level0_col1" class="col_heading level0 col1" >Rear Collision</th>
#       <th id="T_a5f86_level0_col2" class="col_heading level0 col2" >Side Collision</th>
#       <th id="T_a5f86_level0_col3" class="col_heading level0 col3" >UNKNOWN</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >fraud_reported</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5f86_level0_row0" class="row_heading level0 row0" >N</th>
#       <td id="T_a5f86_row0_col0" class="data row0 col0" >0.244186</td>
#       <td id="T_a5f86_row0_col1" class="data row0 col1" >0.270764</td>
#       <td id="T_a5f86_row0_col2" class="data row0 col2" >0.257475</td>
#       <td id="T_a5f86_row0_col3" class="data row0 col3" >0.227575</td>
#     </tr>
#     <tr>
#       <th id="T_a5f86_level0_row1" class="row_heading level0 row1" >Y</th>
#       <td id="T_a5f86_row1_col0" class="data row1 col0" >0.287879</td>
#       <td id="T_a5f86_row1_col1" class="data row1 col1" >0.348485</td>
#       <td id="T_a5f86_row1_col2" class="data row1 col2" >0.287879</td>
#       <td id="T_a5f86_row1_col3" class="data row1 col3" >0.075758</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_0b36f_row0_col0, #T_0b36f_row1_col1, #T_0b36f_row1_col2, #T_0b36f_row1_col3 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_0b36f_row0_col1, #T_0b36f_row0_col2, #T_0b36f_row0_col3, #T_0b36f_row1_col0 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0b36f">
#   <thead>
#     <tr>
#       <th class="index_name level0" >incident_severity</th>
#       <th id="T_0b36f_level0_col0" class="col_heading level0 col0" >Major Damage</th>
#       <th id="T_0b36f_level0_col1" class="col_heading level0 col1" >Minor Damage</th>
#       <th id="T_0b36f_level0_col2" class="col_heading level0 col2" >Total Loss</th>
#       <th id="T_0b36f_level0_col3" class="col_heading level0 col3" >Trivial Damage</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >fraud_reported</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b36f_level0_row0" class="row_heading level0 row0" >N</th>
#       <td id="T_0b36f_row0_col0" class="data row0 col0" >0.146179</td>
#       <td id="T_0b36f_row0_col1" class="data row0 col1" >0.420266</td>
#       <td id="T_0b36f_row0_col2" class="data row0 col2" >0.318937</td>
#       <td id="T_0b36f_row0_col3" class="data row0 col3" >0.114618</td>
#     </tr>
#     <tr>
#       <th id="T_0b36f_level0_row1" class="row_heading level0 row1" >Y</th>
#       <td id="T_0b36f_row1_col0" class="data row1 col0" >0.661616</td>
#       <td id="T_0b36f_row1_col1" class="data row1 col1" >0.141414</td>
#       <td id="T_0b36f_row1_col2" class="data row1 col2" >0.166667</td>
#       <td id="T_0b36f_row1_col3" class="data row1 col3" >0.030303</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_61b05_row0_col0, #T_61b05_row1_col1, #T_61b05_row1_col2 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_61b05_row0_col1, #T_61b05_row0_col2, #T_61b05_row1_col0 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# </style>
# <table id="T_61b05">
#   <thead>
#     <tr>
#       <th class="index_name level0" >property_damage</th>
#       <th id="T_61b05_level0_col0" class="col_heading level0 col0" >NO</th>
#       <th id="T_61b05_level0_col1" class="col_heading level0 col1" >UNKNOWN</th>
#       <th id="T_61b05_level0_col2" class="col_heading level0 col2" >YES</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >fraud_reported</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61b05_level0_row0" class="row_heading level0 row0" >N</th>
#       <td id="T_61b05_row0_col0" class="data row0 col0" >0.378738</td>
#       <td id="T_61b05_row0_col1" class="data row0 col1" >0.338870</td>
#       <td id="T_61b05_row0_col2" class="data row0 col2" >0.282392</td>
#     </tr>
#     <tr>
#       <th id="T_61b05_level0_row1" class="row_heading level0 row1" >Y</th>
#       <td id="T_61b05_row1_col0" class="data row1 col0" >0.272727</td>
#       <td id="T_61b05_row1_col1" class="data row1 col1" >0.414141</td>
#       <td id="T_61b05_row1_col2" class="data row1 col2" >0.313131</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_8f165_row0_col0, #T_8f165_row0_col1, #T_8f165_row1_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_8f165_row0_col2, #T_8f165_row1_col0, #T_8f165_row1_col1 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8f165">
#   <thead>
#     <tr>
#       <th class="index_name level0" >police_report_available</th>
#       <th id="T_8f165_level0_col0" class="col_heading level0 col0" >NO</th>
#       <th id="T_8f165_level0_col1" class="col_heading level0 col1" >UNKNOWN</th>
#       <th id="T_8f165_level0_col2" class="col_heading level0 col2" >YES</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >fraud_reported</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8f165_level0_row0" class="row_heading level0 row0" >N</th>
#       <td id="T_8f165_row0_col0" class="data row0 col0" >0.340532</td>
#       <td id="T_8f165_row0_col1" class="data row0 col1" >0.330565</td>
#       <td id="T_8f165_row0_col2" class="data row0 col2" >0.328904</td>
#     </tr>
#     <tr>
#       <th id="T_8f165_level0_row1" class="row_heading level0 row1" >Y</th>
#       <td id="T_8f165_row1_col0" class="data row1 col0" >0.368687</td>
#       <td id="T_8f165_row1_col1" class="data row1 col1" >0.348485</td>
#       <td id="T_8f165_row1_col2" class="data row1 col2" >0.282828</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_39f6f_row0_col0, #T_39f6f_row1_col1 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_39f6f_row0_col1, #T_39f6f_row1_col0 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# </style>
# <table id="T_39f6f">
#   <thead>
#     <tr>
#       <th class="index_name level0" >fraud_reported</th>
#       <th id="T_39f6f_level0_col0" class="col_heading level0 col0" >N</th>
#       <th id="T_39f6f_level0_col1" class="col_heading level0 col1" >Y</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >fraud_reported</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_39f6f_level0_row0" class="row_heading level0 row0" >N</th>
#       <td id="T_39f6f_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_39f6f_row0_col1" class="data row0 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_39f6f_level0_row1" class="row_heading level0 row1" >Y</th>
#       <td id="T_39f6f_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_39f6f_row1_col1" class="data row1 col1" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# These tables show few categoric features do not have significant difference between target of **fraud (Y)** and **non-fraud (N)** such as:<br>
# **`policy_deductable, policy_state, police_report_available, insured_sex, policy_csl, policy_state`**

# %% [markdown]
# ## <a id='toc2_7_'></a>[<b>5. Barplot of Categoric Features</b>](#toc0_)

# %% [markdown]
# Here, we gonna visualize the **pd.crosstab** above into `countplot`
#
# We can plot the categorical relationships above to get a better feel of the interactions. <br>
# We will create count plots of the data using **Seaborn’s `catplot()`** function and provide **`kind=count`** as a parameter
#
# Notice the parameter **`sharey=False`** in catplot which disassociates the y-scales for each target class so that we can **better view and compare the relationships**.

# %%
plt.figure(figsize=(12, 3))
count = 0

for i in range(len(list_cat_col) // 2):
    for j in range(2):

        if count >= len(list_cat_col):
            break

        c = sns.catplot(data=train_set, x=list_cat_col[count], col='fraud_reported', kind='count',
                        sharey=False, height=3.5, aspect=1.5)

        # Access the individual axes (subplots) within the FacetGrid
        for ax in c.axes.flat:
            ax.tick_params(axis='x', labelsize=8)
            ax.tick_params(axis='y', labelsize=8)
            ax.set_xticklabels(ax.get_xticklabels(), rotation=45, fontsize=7)

        count += 1

plt.tight_layout()
plt.show()

# %% [markdown]
# **`property_damage`, `bodily_injuries`, `witnesses`, `insured_hobbies`, `collision_type`, `incident_severity`, `authorities_contacted`, <br>
# `incident_state`, `incident_city`, `property_damage`, `auto_make`, `auto_model`**
#
# These features show a **significant relationship between target (fraud_reported)**. <br>
# Visibly, they **exhibit distinct patterns that are different from each other**. These patterns in the features are strongly associated with the occurrence of fraud, making them crucial indicators for predicting fraudulent activities.

# %% [markdown]
# ## <a id='toc2_8_'></a>[<b>6. Group numeric features by categorical features</b>](#toc0_)

# %% [markdown]
# We will use the **`pd.groupby()`** function to group our data into categories and observe how the numeric features are distributed by calculating a metric such as
#
# **`mean, median, and standard deviation`** across the classes.

# %%
for col in list_cat_col:
    if train_set[col].nunique() <= 5:
        display(train_set.groupby(col)[list_num_col].mean().style.background_gradient(cmap='Blues'))
# Out:
# <style type="text/css">
# #T_2a3d5_row0_col0, #T_2a3d5_row0_col1, #T_2a3d5_row0_col2, #T_2a3d5_row0_col4, #T_2a3d5_row0_col5, #T_2a3d5_row0_col8, #T_2a3d5_row0_col9, #T_2a3d5_row0_col10, #T_2a3d5_row0_col11, #T_2a3d5_row1_col6, #T_2a3d5_row2_col3, #T_2a3d5_row2_col7 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_2a3d5_row0_col3, #T_2a3d5_row1_col0, #T_2a3d5_row1_col1, #T_2a3d5_row1_col2, #T_2a3d5_row1_col5, #T_2a3d5_row1_col7, #T_2a3d5_row1_col8, #T_2a3d5_row1_col9, #T_2a3d5_row1_col10, #T_2a3d5_row1_col11, #T_2a3d5_row2_col4, #T_2a3d5_row2_col6 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_2a3d5_row0_col6 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_2a3d5_row0_col7 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_2a3d5_row1_col3 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_2a3d5_row1_col4 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_2a3d5_row2_col0 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_2a3d5_row2_col1 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_2a3d5_row2_col2 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_2a3d5_row2_col5 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_2a3d5_row2_col8 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_2a3d5_row2_col9 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_2a3d5_row2_col10 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_2a3d5_row2_col11 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# </style>
# <table id="T_2a3d5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2a3d5_level0_col0" class="col_heading level0 col0" >months_as_customer</th>
#       <th id="T_2a3d5_level0_col1" class="col_heading level0 col1" >age</th>
#       <th id="T_2a3d5_level0_col2" class="col_heading level0 col2" >policy_number</th>
#       <th id="T_2a3d5_level0_col3" class="col_heading level0 col3" >policy_annual_premium</th>
#       <th id="T_2a3d5_level0_col4" class="col_heading level0 col4" >insured_zip</th>
#       <th id="T_2a3d5_level0_col5" class="col_heading level0 col5" >capital_gains</th>
#       <th id="T_2a3d5_level0_col6" class="col_heading level0 col6" >capital_loss</th>
#       <th id="T_2a3d5_level0_col7" class="col_heading level0 col7" >incident_hour_of_the_day</th>
#       <th id="T_2a3d5_level0_col8" class="col_heading level0 col8" >total_claim_amount</th>
#       <th id="T_2a3d5_level0_col9" class="col_heading level0 col9" >injury_claim</th>
#       <th id="T_2a3d5_level0_col10" class="col_heading level0 col10" >property_claim</th>
#       <th id="T_2a3d5_level0_col11" class="col_heading level0 col11" >vehicle_claim</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >policy_deductable</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2a3d5_level0_row0" class="row_heading level0 row0" >1000</th>
#       <td id="T_2a3d5_row0_col0" class="data row0 col0" >195.858209</td>
#       <td id="T_2a3d5_row0_col1" class="data row0 col1" >38.477612</td>
#       <td id="T_2a3d5_row0_col2" class="data row0 col2" >535343.317164</td>
#       <td id="T_2a3d5_row0_col3" class="data row0 col3" >1272.660448</td>
#       <td id="T_2a3d5_row0_col4" class="data row0 col4" >496124.138060</td>
#       <td id="T_2a3d5_row0_col5" class="data row0 col5" >22939.552239</td>
#       <td id="T_2a3d5_row0_col6" class="data row0 col6" >-26857.089552</td>
#       <td id="T_2a3d5_row0_col7" class="data row0 col7" >11.768657</td>
#       <td id="T_2a3d5_row0_col8" class="data row0 col8" >50640.037313</td>
#       <td id="T_2a3d5_row0_col9" class="data row0 col9" >7035.261194</td>
#       <td id="T_2a3d5_row0_col10" class="data row0 col10" >6780.634328</td>
#       <td id="T_2a3d5_row0_col11" class="data row0 col11" >36824.141791</td>
#     </tr>
#     <tr>
#       <th id="T_2a3d5_level0_row1" class="row_heading level0 row1" >2000</th>
#       <td id="T_2a3d5_row1_col0" class="data row1 col0" >208.486275</td>
#       <td id="T_2a3d5_row1_col1" class="data row1 col1" >39.364706</td>
#       <td id="T_2a3d5_row1_col2" class="data row1 col2" >549448.584314</td>
#       <td id="T_2a3d5_row1_col3" class="data row1 col3" >1255.117647</td>
#       <td id="T_2a3d5_row1_col4" class="data row1 col4" >504233.329412</td>
#       <td id="T_2a3d5_row1_col5" class="data row1 col5" >27021.568627</td>
#       <td id="T_2a3d5_row1_col6" class="data row1 col6" >-27859.607843</td>
#       <td id="T_2a3d5_row1_col7" class="data row1 col7" >12.266667</td>
#       <td id="T_2a3d5_row1_col8" class="data row1 col8" >53835.098039</td>
#       <td id="T_2a3d5_row1_col9" class="data row1 col9" >7661.372549</td>
#       <td id="T_2a3d5_row1_col10" class="data row1 col10" >7850.980392</td>
#       <td id="T_2a3d5_row1_col11" class="data row1 col11" >38322.745098</td>
#     </tr>
#     <tr>
#       <th id="T_2a3d5_level0_row2" class="row_heading level0 row2" >500</th>
#       <td id="T_2a3d5_row2_col0" class="data row2 col0" >207.750903</td>
#       <td id="T_2a3d5_row2_col1" class="data row2 col1" >39.216606</td>
#       <td id="T_2a3d5_row2_col2" class="data row2 col2" >549279.270758</td>
#       <td id="T_2a3d5_row2_col3" class="data row2 col3" >1245.653430</td>
#       <td id="T_2a3d5_row2_col4" class="data row2 col4" >506715.129964</td>
#       <td id="T_2a3d5_row2_col5" class="data row2 col5" >23808.664260</td>
#       <td id="T_2a3d5_row2_col6" class="data row2 col6" >-24902.527076</td>
#       <td id="T_2a3d5_row2_col7" class="data row2 col7" >10.732852</td>
#       <td id="T_2a3d5_row2_col8" class="data row2 col8" >52128.375451</td>
#       <td id="T_2a3d5_row2_col9" class="data row2 col9" >7435.920578</td>
#       <td id="T_2a3d5_row2_col10" class="data row2 col10" >7365.234657</td>
#       <td id="T_2a3d5_row2_col11" class="data row2 col11" >37327.220217</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_8d775_row0_col0, #T_8d775_row0_col1, #T_8d775_row0_col7, #T_8d775_row0_col8, #T_8d775_row0_col9, #T_8d775_row0_col10, #T_8d775_row0_col11, #T_8d775_row1_col3, #T_8d775_row1_col4, #T_8d775_row1_col5, #T_8d775_row1_col6, #T_8d775_row3_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_8d775_row0_col2 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_8d775_row0_col3, #T_8d775_row1_col0, #T_8d775_row1_col2, #T_8d775_row1_col7, #T_8d775_row1_col8, #T_8d775_row1_col9, #T_8d775_row1_col10, #T_8d775_row1_col11, #T_8d775_row3_col1, #T_8d775_row3_col4, #T_8d775_row3_col5, #T_8d775_row3_col6 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_8d775_row0_col4 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_8d775_row0_col5 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_8d775_row0_col6 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_8d775_row1_col1 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_8d775_row2_col0 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_8d775_row2_col1 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_8d775_row2_col2 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_8d775_row2_col3 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_8d775_row2_col4 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_8d775_row2_col5 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_8d775_row2_col6 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_8d775_row2_col7 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_8d775_row2_col8 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_8d775_row2_col9 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_8d775_row2_col10 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_8d775_row2_col11 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_8d775_row3_col0 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_8d775_row3_col3 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_8d775_row3_col7 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_8d775_row3_col8 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_8d775_row3_col9 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_8d775_row3_col10 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_8d775_row3_col11 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8d775">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8d775_level0_col0" class="col_heading level0 col0" >months_as_customer</th>
#       <th id="T_8d775_level0_col1" class="col_heading level0 col1" >age</th>
#       <th id="T_8d775_level0_col2" class="col_heading level0 col2" >policy_number</th>
#       <th id="T_8d775_level0_col3" class="col_heading level0 col3" >policy_annual_premium</th>
#       <th id="T_8d775_level0_col4" class="col_heading level0 col4" >insured_zip</th>
#       <th id="T_8d775_level0_col5" class="col_heading level0 col5" >capital_gains</th>
#       <th id="T_8d775_level0_col6" class="col_heading level0 col6" >capital_loss</th>
#       <th id="T_8d775_level0_col7" class="col_heading level0 col7" >incident_hour_of_the_day</th>
#       <th id="T_8d775_level0_col8" class="col_heading level0 col8" >total_claim_amount</th>
#       <th id="T_8d775_level0_col9" class="col_heading level0 col9" >injury_claim</th>
#       <th id="T_8d775_level0_col10" class="col_heading level0 col10" >property_claim</th>
#       <th id="T_8d775_level0_col11" class="col_heading level0 col11" >vehicle_claim</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >number_of_vehicles_involved</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d775_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_8d775_row0_col0" class="data row0 col0" >200.390558</td>
#       <td id="T_8d775_row0_col1" class="data row0 col1" >38.759657</td>
#       <td id="T_8d775_row0_col2" class="data row0 col2" >541311.143777</td>
#       <td id="T_8d775_row0_col3" class="data row0 col3" >1271.030043</td>
#       <td id="T_8d775_row0_col4" class="data row0 col4" >502237.195279</td>
#       <td id="T_8d775_row0_col5" class="data row0 col5" >23759.442060</td>
#       <td id="T_8d775_row0_col6" class="data row0 col6" >-26340.557940</td>
#       <td id="T_8d775_row0_col7" class="data row0 col7" >10.652361</td>
#       <td id="T_8d775_row0_col8" class="data row0 col8" >45209.763948</td>
#       <td id="T_8d775_row0_col9" class="data row0 col9" >6272.982833</td>
#       <td id="T_8d775_row0_col10" class="data row0 col10" >6319.935622</td>
#       <td id="T_8d775_row0_col11" class="data row0 col11" >32616.845494</td>
#     </tr>
#     <tr>
#       <th id="T_8d775_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_8d775_row1_col0" class="data row1 col0" >221.130435</td>
#       <td id="T_8d775_row1_col1" class="data row1 col1" >38.782609</td>
#       <td id="T_8d775_row1_col2" class="data row1 col2" >578097.782609</td>
#       <td id="T_8d775_row1_col3" class="data row1 col3" >1204.652174</td>
#       <td id="T_8d775_row1_col4" class="data row1 col4" >485430.478261</td>
#       <td id="T_8d775_row1_col5" class="data row1 col5" >18113.043478</td>
#       <td id="T_8d775_row1_col6" class="data row1 col6" >-28730.434783</td>
#       <td id="T_8d775_row1_col7" class="data row1 col7" >14.434783</td>
#       <td id="T_8d775_row1_col8" class="data row1 col8" >66323.913043</td>
#       <td id="T_8d775_row1_col9" class="data row1 col9" >9226.956522</td>
#       <td id="T_8d775_row1_col10" class="data row1 col10" >9990.869565</td>
#       <td id="T_8d775_row1_col11" class="data row1 col11" >47106.086957</td>
#     </tr>
#     <tr>
#       <th id="T_8d775_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_8d775_row2_col0" class="data row2 col0" >207.930070</td>
#       <td id="T_8d775_row2_col1" class="data row2 col1" >39.416084</td>
#       <td id="T_8d775_row2_col2" class="data row2 col2" >549069.884615</td>
#       <td id="T_8d775_row2_col3" class="data row2 col3" >1241.636364</td>
#       <td id="T_8d775_row2_col4" class="data row2 col4" >502304.027972</td>
#       <td id="T_8d775_row2_col5" class="data row2 col5" >25420.629371</td>
#       <td id="T_8d775_row2_col6" class="data row2 col6" >-27294.405594</td>
#       <td id="T_8d775_row2_col7" class="data row2 col7" >12.884615</td>
#       <td id="T_8d775_row2_col8" class="data row2 col8" >61667.902098</td>
#       <td id="T_8d775_row2_col9" class="data row2 col9" >8947.202797</td>
#       <td id="T_8d775_row2_col10" class="data row2 col10" >8581.188811</td>
#       <td id="T_8d775_row2_col11" class="data row2 col11" >44139.510490</td>
#     </tr>
#     <tr>
#       <th id="T_8d775_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_8d775_row3_col0" class="data row3 col0" >210.600000</td>
#       <td id="T_8d775_row3_col1" class="data row3 col1" >39.440000</td>
#       <td id="T_8d775_row3_col2" class="data row3 col2" >526021.080000</td>
#       <td id="T_8d775_row3_col3" class="data row3 col3" >1242.360000</td>
#       <td id="T_8d775_row3_col4" class="data row3 col4" >521378.920000</td>
#       <td id="T_8d775_row3_col5" class="data row3 col5" >34980.000000</td>
#       <td id="T_8d775_row3_col6" class="data row3 col6" >-18328.000000</td>
#       <td id="T_8d775_row3_col7" class="data row3 col7" >10.960000</td>
#       <td id="T_8d775_row3_col8" class="data row3 col8" >60352.800000</td>
#       <td id="T_8d775_row3_col9" class="data row3 col9" >8180.800000</td>
#       <td id="T_8d775_row3_col10" class="data row3 col10" >9211.200000</td>
#       <td id="T_8d775_row3_col11" class="data row3 c
# <style type="text/css">
# #T_1628f_row0_col0 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_1628f_row0_col1 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_1628f_row0_col2 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_1628f_row0_col3, #T_1628f_row0_col5, #T_1628f_row1_col0, #T_1628f_row1_col1, #T_1628f_row1_col4, #T_1628f_row1_col7, #T_1628f_row1_col8, #T_1628f_row1_col9, #T_1628f_row1_col10, #T_1628f_row1_col11, #T_1628f_row2_col2, #T_1628f_row2_col6 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_1628f_row0_col4 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_1628f_row0_col6 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_1628f_row0_col7, #T_1628f_row1_col2, #T_1628f_row1_col6, #T_1628f_row2_col0, #T_1628f_row2_col1, #T_1628f_row2_col3, #T_1628f_row2_col4, #T_1628f_row2_col5, #T_1628f_row2_col8, #T_1628f_row2_col9, #T_1628f_row2_col10, #T_1628f_row2_col11 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_1628f_row0_col8 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_1628f_row0_col9 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_1628f_row0_col10 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_1628f_row0_col11 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_1628f_row1_col3 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_1628f_row1_col5 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_1628f_row2_col7 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# </style>
# <table id="T_1628f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1628f_level0_col0" class="col_heading level0 col0" >months_as_customer</th>
#       <th id="T_1628f_level0_col1" class="col_heading level0 col1" >age</th>
#       <th id="T_1628f_level0_col2" class="col_heading level0 col2" >policy_number</th>
#       <th id="T_1628f_level0_col3" class="col_heading level0 col3" >policy_annual_premium</th>
#       <th id="T_1628f_level0_col4" class="col_heading level0 col4" >insured_zip</th>
#       <th id="T_1628f_level0_col5" class="col_heading level0 col5" >capital_gains</th>
#       <th id="T_1628f_level0_col6" class="col_heading level0 col6" >capital_loss</th>
#       <th id="T_1628f_level0_col7" class="col_heading level0 col7" >incident_hour_of_the_day</th>
#       <th id="T_1628f_level0_col8" class="col_heading level0 col8" >total_claim_amount</th>
#       <th id="T_1628f_level0_col9" class="col_heading level0 col9" >injury_claim</th>
#       <th id="T_1628f_level0_col10" class="col_heading level0 col10" >property_claim</th>
#       <th id="T_1628f_level0_col11" class="col_heading level0 col11" >vehicle_claim</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >bodily_injuries</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1628f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1628f_row0_col0" class="data row0 col0" >205.974638</td>
#       <td id="T_1628f_row0_col1" class="data row0 col1" >39.188406</td>
#       <td id="T_1628f_row0_col2" class="data row0 col2" >539556.586957</td>
#       <td id="T_1628f_row0_col3" class="data row0 col3" >1253.282609</td>
#       <td id="T_1628f_row0_col4" class="data row0 col4" >502198.699275</td>
#       <td id="T_1628f_row0_col5" class="data row0 col5" >22382.246377</td>
#       <td id="T_1628f_row0_col6" class="data row0 col6" >-25657.246377</td>
#       <td id="T_1628f_row0_col7" class="data row0 col7" >11.818841</td>
#       <td id="T_1628f_row0_col8" class="data row0 col8" >50703.079710</td>
#       <td id="T_1628f_row0_col9" class="data row0 col9" >7243.804348</td>
#       <td id="T_1628f_row0_col10" class="data row0 col10" >7127.826087</td>
#       <td id="T_1628f_row0_col11" class="data row0 col11" >36331.449275</td>
#     </tr>
#     <tr>
#       <th id="T_1628f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1628f_row1_col0" class="data row1 col0" >196.924603</td>
#       <td id="T_1628f_row1_col1" class="data row1 col1" >38.496032</td>
#       <td id="T_1628f_row1_col2" class="data row1 col2" >558315.833333</td>
#       <td id="T_1628f_row1_col3" class="data row1 col3" >1258.642857</td>
#       <td id="T_1628f_row1_col4" class="data row1 col4" >499857.976190</td>
#       <td id="T_1628f_row1_col5" class="data row1 col5" >25463.888889</td>
#       <td id="T_1628f_row1_col6" class="data row1 col6" >-25335.317460</td>
#       <td id="T_1628f_row1_col7" class="data row1 col7" >11.420635</td>
#       <td id="T_1628f_row1_col8" class="data row1 col8" >49588.174603</td>
#       <td id="T_1628f_row1_col9" class="data row1 col9" >6734.285714</td>
#       <td id="T_1628f_row1_col10" class="data row1 col10" >6788.293651</td>
#       <td id="T_1628f_row1_col11" class="data row1 col11" >36065.595238</td>
#     </tr>
#     <tr>
#       <th id="T_1628f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1628f_row2_col0" class="data row2 col0" >208.555147</td>
#       <td id="T_1628f_row2_col1" class="data row2 col1" >39.323529</td>
#       <td id="T_1628f_row2_col2" class="data row2 col2" >537200.544118</td>
#       <td id="T_1628f_row2_col3" class="data row2 col3" >1261.360294</td>
#       <td id="T_1628f_row2_col4" class="data row2 col4" >504889.000000</td>
#       <td id="T_1628f_row2_col5" class="data row2 col5" >25878.308824</td>
#       <td id="T_1628f_row2_col6" class="data row2 col6" >-28433.823529</td>
#       <td id="T_1628f_row2_col7" class="data row2 col7" >11.452206</td>
#       <td id="T_1628f_row2_col8" class="data row2 col8" >56061.654412</td>
#       <td id="T_1628f_row2_col9" class="data row2 col9" >8097.500000</td>
#       <td id="T_1628f_row2_col10" class="data row2 col10" >8020.036765</td>
#       <td id="T_1628f_row2_col11" class="data row2 col11" >39944.117647</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_49c2b_row0_col0, #T_49c2b_row0_col1, #T_49c2b_row1_col2, #T_49c2b_row1_col7, #T_49c2b_row1_col8, #T_49c2b_row1_col9, #T_49c2b_row1_col10, #T_49c2b_row1_col11, #T_49c2b_row2_col3, #T_49c2b_row2_col4, #T_49c2b_row2_col5, #T_49c2b_row2_col6 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_49c2b_row0_col2 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_49c2b_row0_col3 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_49c2b_row0_col4 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_49c2b_row0_col5, #T_49c2b_row0_col6, #T_49c2b_row0_col7, #T_49c2b_row0_col9, #T_49c2b_row0_col11, #T_49c2b_row1_col3, #T_49c2b_row1_col4, #T_49c2b_row2_col1, #T_49c2b_row2_col2, #T_49c2b_row2_col8, #T_49c2b_row3_col0, #T_49c2b_row3_col10 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_49c2b_row0_col8 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_49c2b_row0_col10 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_49c2b_row1_col0 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_49c2b_row1_col1 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_49c2b_row1_col5 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_49c2b_row1_col6 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_49c2b_row2_col0, #T_49c2b_row3_col7 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_49c2b_row2_col7 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_49c2b_row2_col9 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_49c2b_row2_col10 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_49c2b_row2_col11 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_49c2b_row3_col1 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_49c2b_row3_col2 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_49c2b_row3_col3 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_49c2b_row3_col4 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_49c2b_row3_col5 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_49c2b_row3_col6 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_49c2b_row3_col8 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_49c2b_row3_col9 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_49c2b_row3_col11 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# </style>
# <table id="T_49c2b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_49c2b_level0_col0" class="col_heading level0 col0" >months_as_customer</th>
#       <th id="T_49c2b_level0_col1" class="col_heading level0 col1" >age</th>
#       <th id="T_49c2b_level0_col2" class="col_heading level0 col2" >policy_number</th>
#       <th id="T_49c2b_level0_col3" class="col_heading level0 col3" >policy_annual_premium</th>
#       <th id="T_49c2b_level0_col4" class="col_heading level0 col4" >insured_zip</th>
#       <th id="T_49c2b_level0_col5" class="col_heading level0 col5" >capital_gains</th>
#       <th id="T_49c2b_level0_col6" class="col_heading level0 col6" >capital_loss</th>
#       <th id="T_49c2b_level0_col7" class="col_heading level0 col7" >incident_hour_of_the_day</th>
#       <th id="T_49c2b_level0_col8" class="col_heading level0 col8" >total_claim_amount</th>
#       <th id="T_49c2b_level0_col9" class="col_heading level0 col9" >injury_claim</th>
#       <th id="T_49c2b_level0_col10" class="col_heading level0 col10" >property_claim</th>
#       <th id="T_49c2b_level0_col11" class="col_heading level0 col11" >vehicle_claim</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >witnesses</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_49c2b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_49c2b_row0_col0" class="data row0 col0" >196.923469</td>
#       <td id="T_49c2b_row0_col1" class="data row0 col1" >38.408163</td>
#       <td id="T_49c2b_row0_col2" class="data row0 col2" >545161.153061</td>
#       <td id="T_49c2b_row0_col3" class="data row0 col3" >1256.734694</td>
#       <td id="T_49c2b_row0_col4" class="data row0 col4" >500489.653061</td>
#       <td id="T_49c2b_row0_col5" class="data row0 col5" >28283.163265</td>
#       <td id="T_49c2b_row0_col6" class="data row0 col6" >-24794.897959</td>
#       <td id="T_49c2b_row0_col7" class="data row0 col7" >11.913265</td>
#       <td id="T_49c2b_row0_col8" class="data row0 col8" >53745.204082</td>
#       <td id="T_49c2b_row0_col9" class="data row0 col9" >7886.173469</td>
#       <td id="T_49c2b_row0_col10" class="data row0 col10" >7146.479592</td>
#       <td id="T_49c2b_row0_col11" class="data row0 col11" >38712.551020</td>
#     </tr>
#     <tr>
#       <th id="T_49c2b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_49c2b_row1_col0" class="data row1 col0" >205.221154</td>
#       <td id="T_49c2b_row1_col1" class="data row1 col1" >39.197115</td>
#       <td id="T_49c2b_row1_col2" class="data row1 col2" >531282.375000</td>
#       <td id="T_49c2b_row1_col3" class="data row1 col3" >1281.956731</td>
#       <td id="T_49c2b_row1_col4" class="data row1 col4" >507598.649038</td>
#       <td id="T_49c2b_row1_col5" class="data row1 col5" >22992.788462</td>
#       <td id="T_49c2b_row1_col6" class="data row1 col6" >-25381.730769</td>
#       <td id="T_49c2b_row1_col7" class="data row1 col7" >10.721154</td>
#       <td id="T_49c2b_row1_col8" class="data row1 col8" >50043.701923</td>
#       <td id="T_49c2b_row1_col9" class="data row1 col9" >6951.778846</td>
#       <td id="T_49c2b_row1_col10" class="data row1 col10" >7063.990385</td>
#       <td id="T_49c2b_row1_col11" class="data row1 col11" >36027.932692</td>
#     </tr>
#     <tr>
#       <th id="T_49c2b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_49c2b_row2_col0" class="data row2 col0" >206.328431</td>
#       <td id="T_49c2b_row2_col1" class="data row2 col1" >39.382353</td>
#       <td id="T_49c2b_row2_col2" class="data row2 col2" >561203.838235</td>
#       <td id="T_49c2b_row2_col3" class="data row2 col3" >1242.803922</td>
#       <td id="T_49c2b_row2_col4" class="data row2 col4" >499119.941176</td>
#       <td id="T_49c2b_row2_col5" class="data row2 col5" >20677.941176</td>
#       <td id="T_49c2b_row2_col6" class="data row2 col6" >-29674.019608</td>
#       <td id="T_49c2b_row2_col7" class="data row2 col7" >11.892157</td>
#       <td id="T_49c2b_row2_col8" class="data row2 col8" >53760.392157</td>
#       <td id="T_49c2b_row2_col9" class="data row2 col9" >7572.892157</td>
#       <td id="T_49c2b_row2_col10" class="data row2 col10" >7516.862745</td>
#       <td id="T_49c2b_row2_col11" class="data row2 col11" >38670.637255</td>
#     </tr>
#     <tr>
#       <th id="T_49c2b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_49c2b_row3_col0" class="data row3 col0" >207.432292</td>
#       <td id="T_49c2b_row3_col1" class="data row3 col1" >39.052083</td>
#       <td id="T_49c2b_row3_col2" class="data row3 col2" >541082.567708</td>
#       <td id="T_49c2b_row3_col3" class="data row3 col3" >1248.307292</td>
#       <td id="T_49c2b_row3_col4" class="data row3 col4" >502103.645833</td>
#       <td id="T_49c2b_row3_col5" class="data row3 col5" >26505.208333</td>
#       <td id="T_49c2b_row3_col6" class="data row3 col6" >-26079.166667</td>
#       <td id="T_49c2b_row3_col7" class="data row3 col7" >11.791667</td>
#       <td id="T_49c2b_row3_col8" class="data row3 col8" >51191.510417</td>
#       <td id="T_49c2b_row3_col9" class="data row3 col9" >7095.416667</td>
#       <td id="T_49c2b_row3_col10" class="data row3 col10" >7582.916667</td>
#       <td id="T_49c2b_row3_col11" class="data row3 col11" >36513.177083</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_92897_row0_col0, #T_92897_row0_col1, #T_92897_row0_col3, #T_92897_row0_col6, #T_92897_row0_col8, #T_92897_row0_col9, #T_92897_row0_col10, #T_92897_row0_col11, #T_92897_row1_col2, #T_92897_row1_col4, #T_92897_row2_col5, #T_92897_row2_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_92897_row0_col2, #T_92897_row0_col4, #T_92897_row0_col5, #T_92897_row0_col7, #T_92897_row1_col0, #T_92897_row1_col1, #T_92897_row1_col6, #T_92897_row1_col10, #T_92897_row2_col3, #T_92897_row2_col8, #T_92897_row2_col9, #T_92897_row2_col11 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_92897_row1_col3 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_92897_row1_col5 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_92897_row1_col7 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_92897_row1_col8 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_92897_row1_col9 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_92897_row1_col11 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_92897_row2_col0 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_92897_row2_col1 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_92897_row2_col2 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_92897_row2_col4 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_92897_row2_col6 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_92897_row2_col10 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# </style>
# <table id="T_92897">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_92897_level0_col0" class="col_heading level0 col0" >months_as_customer</th>
#       <th id="T_92897_level0_col1" class="col_heading level0 col1" >age</th>
#       <th id="T_92897_level0_col2" class="col_heading level0 col2" >policy_number</th>
#       <th id="T_92897_level0_col3" class="col_heading level0 col3" >policy_annual_premium</th>
#       <th id="T_92897_level0_col4" class="col_heading level0 col4" >insured_zip</th>
#       <th id="T_92897_level0_col5" class="col_heading level0 col5" >capital_gains</th>
#       <th id="T_92897_level0_col6" class="col_heading level0 col6" >capital_loss</th>
#       <th id="T_92897_level0_col7" class="col_heading level0 col7" >incident_hour_of_the_day</th>
#       <th id="T_92897_level0_col8" class="col_heading level0 col8" >total_claim_amount</th>
#       <th id="T_92897_level0_col9" class="col_heading level0 col9" >injury_claim</th>
#       <th id="T_92897_level0_col10" class="col_heading level0 col10" >property_claim</th>
#       <th id="T_92897_level0_col11" class="col_heading level0 col11" >vehicle_claim</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >policy_state</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_92897_level0_row0" class="row_heading level0 row0" >IL</th>
#       <td id="T_92897_row0_col0" class="data row0 col0" >210.124528</td>
#       <td id="T_92897_row0_col1" class="data row0 col1" >39.833962</td>
#       <td id="T_92897_row0_col2" class="data row0 col2" >509861.822642</td>
#       <td id="T_92897_row0_col3" class="data row0 col3" >1259.188679</td>
#       <td id="T_92897_row0_col4" class="data row0 col4" >501032.660377</td>
#       <td id="T_92897_row0_col5" class="data row0 col5" >22318.867925</td>
#       <td id="T_92897_row0_col6" class="data row0 col6" >-24697.735849</td>
#       <td id="T_92897_row0_col7" class="data row0 col7" >11.309434</td>
#       <td id="T_92897_row0_col8" class="data row0 col8" >53207.471698</td>
#       <td id="T_92897_row0_col9" class="data row0 col9" >7778.075472</td>
#       <td id="T_92897_row0_col10" class="data row0 col10" >7523.207547</td>
#       <td id="T_92897_row0_col11" class="data row0 col11" >37906.188679</td>
#     </tr>
#     <tr>
#       <th id="T_92897_level0_row1" class="row_heading level0 row1" >IN</th>
#       <td id="T_92897_row1_col0" class="data row1 col0" >198.640316</td>
#       <td id="T_92897_row1_col1" class="data row1 col1" >38.142292</td>
#       <td id="T_92897_row1_col2" class="data row1 col2" >562086.628458</td>
#       <td id="T_92897_row1_col3" class="data row1 col3" >1257.573123</td>
#       <td id="T_92897_row1_col4" class="data row1 col4" >503583.304348</td>
#       <td id="T_92897_row1_col5" class="data row1 col5" >24598.418972</td>
#       <td id="T_92897_row1_col6" class="data row1 col6" >-29609.486166</td>
#       <td id="T_92897_row1_col7" class="data row1 col7" >11.636364</td>
#       <td id="T_92897_row1_col8" class="data row1 col8" >52009.407115</td>
#       <td id="T_92897_row1_col9" class="data row1 col9" >7376.956522</td>
#       <td id="T_92897_row1_col10" class="data row1 col10" >7168.181818</td>
#       <td id="T_92897_row1_col11" class="data row1 col11" >37464.268775</td>
#     </tr>
#     <tr>
#       <th id="T_92897_level0_row2" class="row_heading level0 row2" >OH</th>
#       <td id="T_92897_row2_col0" class="data row2 col0" >203.056738</td>
#       <td id="T_92897_row2_col1" class="data row2 col1" >39.031915</td>
#       <td id="T_92897_row2_col2" class="data row2 col2" >561739.205674</td>
#       <td id="T_92897_row2_col3" class="data row2 col3" >1256.464539</td>
#       <td id="T_92897_row2_col4" class="data row2 col4" >502555.418440</td>
#       <td id="T_92897_row2_col5" class="data row2 col5" >26579.432624</td>
#       <td id="T_92897_row2_col6" class="data row2 col6" >-25403.546099</td>
#       <td id="T_92897_row2_col7" class="data row2 col7" >11.751773</td>
#       <td id="T_92897_row2_col8" class="data row2 col8" >51349.929078</td>
#       <td id="T_92897_row2_col9" class="data row2 col9" >6990.390071</td>
#       <td id="T_92897_row2_col10" class="data row2 col10" >7277.234043</td>
#       <td id="T_92897_row2_col11" class="data row2 col11" >37082.304965</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_61912_row0_col0, #T_61912_row0_col6, #T_61912_row0_col8, #T_61912_row0_col9, #T_61912_row0_col10, #T_61912_row0_col11, #T_61912_row1_col1, #T_61912_row1_col2, #T_61912_row1_col3, #T_61912_row1_col5, #T_61912_row1_col7, #T_61912_row2_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_61912_row0_col1 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_61912_row0_col2, #T_61912_row0_col3, #T_61912_row0_col4, #T_61912_row0_col5, #T_61912_row1_col6, #T_61912_row1_col8, #T_61912_row1_col10, #T_61912_row1_col11, #T_61912_row2_col0, #T_61912_row2_col1, #T_61912_row2_col7, #T_61912_row2_col9 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_61912_row0_col7 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_61912_row1_col0 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_61912_row1_col4 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_61912_row1_col9 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_61912_row2_col2 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_61912_row2_col3 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_61912_row2_col5 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_61912_row2_col6 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_61912_row2_col8 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_61912_row2_col10 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_61912_row2_col11 {
#   background-color: #cadef0;
#   color: #000000;
# }
# </style>
# <table id="T_61912">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_61912_level0_col0" class="col_heading level0 col0" >months_as_customer</th>
#       <th id="T_61912_level0_col1" class="col_heading level0 col1" >age</th>
#       <th id="T_61912_level0_col2" class="col_heading level0 col2" >policy_number</th>
#       <th id="T_61912_level0_col3" class="col_heading level0 col3" >policy_annual_premium</th>
#       <th id="T_61912_level0_col4" class="col_heading level0 col4" >insured_zip</th>
#       <th id="T_61912_level0_col5" class="col_heading level0 col5" >capital_gains</th>
#       <th id="T_61912_level0_col6" class="col_heading level0 col6" >capital_loss</th>
#       <th id="T_61912_level0_col7" class="col_heading level0 col7" >incident_hour_of_the_day</th>
#       <th id="T_61912_level0_col8" class="col_heading level0 col8" >total_claim_amount</th>
#       <th id="T_61912_level0_col9" class="col_heading level0 col9" >injury_claim</th>
#       <th id="T_61912_level0_col10" class="col_heading level0 col10" >property_claim</th>
#       <th id="T_61912_level0_col11" class="col_heading level0 col11" >vehicle_claim</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >policy_csl</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61912_level0_row0" class="row_heading level0 row0" >100/300</th>
#       <td id="T_61912_row0_col0" class="data row0 col0" >208.806569</td>
#       <td id="T_61912_row0_col1" class="data row0 col1" >39.160584</td>
#       <td id="T_61912_row0_col2" class="data row0 col2" >515748.222628</td>
#       <td id="T_61912_row0_col3" class="data row0 col3" >1254.656934</td>
#       <td id="T_61912_row0_col4" class="data row0 col4" >499822.047445</td>
#       <td id="T_61912_row0_col5" class="data row0 col5" >23759.854015</td>
#       <td id="T_61912_row0_col6" class="data row0 col6" >-24734.306569</td>
#       <td id="T_61912_row0_col7" class="data row0 col7" >11.525547</td>
#       <td id="T_61912_row0_col8" class="data row0 col8" >55290.985401</td>
#       <td id="T_61912_row0_col9" class="data row0 col9" >7959.562044</td>
#       <td id="T_61912_row0_col10" class="data row0 col10" >7771.824818</td>
#       <td id="T_61912_row0_col11" class="data row0 col11" >39559.598540</td>
#     </tr>
#     <tr>
#       <th id="T_61912_level0_row1" class="row_heading level0 row1" >250/500</th>
#       <td id="T_61912_row1_col0" class="data row1 col0" >204.108392</td>
#       <td id="T_61912_row1_col1" class="data row1 col1" >39.223776</td>
#       <td id="T_61912_row1_col2" class="data row1 col2" >568279.489510</td>
#       <td id="T_61912_row1_col3" class="data row1 col3" >1261.888112</td>
#       <td id="T_61912_row1_col4" class="data row1 col4" >503652.867133</td>
#       <td id="T_61912_row1_col5" class="data row1 col5" >24990.909091</td>
#       <td id="T_61912_row1_col6" class="data row1 col6" >-27741.258741</td>
#       <td id="T_61912_row1_col7" class="data row1 col7" >11.741259</td>
#       <td id="T_61912_row1_col8" class="data row1 col8" >50096.748252</td>
#       <td id="T_61912_row1_col9" class="data row1 col9" >7102.132867</td>
#       <td id="T_61912_row1_col10" class="data row1 col10" >6973.391608</td>
#       <td id="T_61912_row1_col11" class="data row1 col11" >36021.223776</td>
#     </tr>
#     <tr>
#       <th id="T_61912_level0_row2" class="row_heading level0 row2" >500/1000</th>
#       <td id="T_61912_row2_col0" class="data row2 col0" >198.387500</td>
#       <td id="T_61912_row2_col1" class="data row2 col1" >38.604167</td>
#       <td id="T_61912_row2_col2" class="data row2 col2" >549536.704167</td>
#       <td id="T_61912_row2_col3" class="data row2 col3" >1256.241667</td>
#       <td id="T_61912_row2_col4" class="data row2 col4" >503770.408333</td>
#       <td id="T_61912_row2_col5" class="data row2 col5" >24898.750000</td>
#       <td id="T_61912_row2_col6" class="data row2 col6" >-27036.250000</td>
#       <td id="T_61912_row2_col7" class="data row2 col7" >11.412500</td>
#       <td id="T_61912_row2_col8" class="data row2 col8" >51090.166667</td>
#       <td id="T_61912_row2_col9" class="data row2 col9" >7028.000000</td>
#       <td id="T_61912_row2_col10" class="data row2 col10" >7231.291667</td>
#       <td id="T_61912_row2_col11" class="data row2 col11" >36830.875000</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_aba1d_row0_col0, #T_aba1d_row0_col1, #T_aba1d_row0_col2, #T_aba1d_row0_col3, #T_aba1d_row0_col5, #T_aba1d_row0_col7, #T_aba1d_row1_col4, #T_aba1d_row1_col6, #T_aba1d_row1_col8, #T_aba1d_row1_col9, #T_aba1d_row1_col10, #T_aba1d_row1_col11 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_aba1d_row0_col4, #T_aba1d_row0_col6, #T_aba1d_row0_col8, #T_aba1d_row0_col9, #T_aba1d_row0_col10, #T_aba1d_row0_col11, #T_aba1d_row1_col0, #T_aba1d_row1_col1, #T_aba1d_row1_col2, #T_aba1d_row1_col3, #T_aba1d_row1_col5, #T_aba1d_row1_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_aba1d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aba1d_level0_col0" class="col_heading level0 col0" >months_as_customer</th>
#       <th id="T_aba1d_level0_col1" class="col_heading level0 col1" >age</th>
#       <th id="T_aba1d_level0_col2" class="col_heading level0 col2" >policy_number</th>
#       <th id="T_aba1d_level0_col3" class="col_heading level0 col3" >policy_annual_premium</th>
#       <th id="T_aba1d_level0_col4" class="col_heading level0 col4" >insured_zip</th>
#       <th id="T_aba1d_level0_col5" class="col_heading level0 col5" >capital_gains</th>
#       <th id="T_aba1d_level0_col6" class="col_heading level0 col6" >capital_loss</th>
#       <th id="T_aba1d_level0_col7" class="col_heading level0 col7" >incident_hour_of_the_day</th>
#       <th id="T_aba1d_level0_col8" class="col_heading level0 col8" >total_claim_amount</th>
#       <th id="T_aba1d_level0_col9" class="col_heading level0 col9" >injury_claim</th>
#       <th id="T_aba1d_level0_col10" class="col_heading level0 col10" >property_claim</th>
#       <th id="T_aba1d_level0_col11" class="col_heading level0 col11" >vehicle_claim</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >insured_sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aba1d_level0_row0" class="row_heading level0 row0" >FEMALE</th>
#       <td id="T_aba1d_row0_col0" class="data row0 col0" >197.518779</td>
#       <td id="T_aba1d_row0_col1" class="data row0 col1" >38.368545</td>
#       <td id="T_aba1d_row0_col2" class="data row0 col2" >543501.328638</td>
#       <td id="T_aba1d_row0_col3" class="data row0 col3" >1243.659624</td>
#       <td id="T_aba1d_row0_col4" class="data row0 col4" >503228.349765</td>
#       <td id="T_aba1d_row0_col5" class="data row0 col5" >24304.460094</td>
#       <td id="T_aba1d_row0_col6" class="data row0 col6" >-25469.953052</td>
#       <td id="T_aba1d_row0_col7" class="data row0 col7" >11.453052</td>
#       <td id="T_aba1d_row0_col8" class="data row0 col8" >52819.647887</td>
#       <td id="T_aba1d_row0_col9" class="data row0 col9" >7450.516432</td>
#       <td id="T_aba1d_row0_col10" class="data row0 col10" >7367.347418</td>
#       <td id="T_aba1d_row0_col11" class="data row0 col11" >38001.784038</td>
#     </tr>
#     <tr>
#       <th id="T_aba1d_level0_row1" class="row_heading level0 row1" >MALE</th>
#       <td id="T_aba1d_row1_col0" class="data row1 col0" >211.385027</td>
#       <td id="T_aba1d_row1_col1" class="data row1 col1" >39.754011</td>
#       <td id="T_aba1d_row1_col2" class="data row1 col2" >545989.812834</td>
#       <td id="T_aba1d_row1_col3" class="data row1 col3" >1273.729947</td>
#       <td id="T_aba1d_row1_col4" class="data row1 col4" >501405.299465</td>
#       <td id="T_aba1d_row1_col5" class="data row1 col5" >24811.764706</td>
#       <td id="T_aba1d_row1_col6" class="data row1 col6" >-27672.994652</td>
#       <td id="T_aba1d_row1_col7" class="data row1 col7" >11.700535</td>
#       <td id="T_aba1d_row1_col8" class="data row1 col8" >51438.155080</td>
#       <td id="T_aba1d_row1_col9" class="data row1 col9" >7285.909091</td>
#       <td id="T_aba1d_row1_col10" class="data row1 col10" >7275.106952</td>
#       <td id="T_aba1d_row1_col11" class="data row1 col11" >36877.139037</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_362a2_row0_col0, #T_362a2_row0_col1, #T_362a2_row0_col5, #T_362a2_row0_col7, #T_362a2_row2_col3, #T_362a2_row2_col8, #T_362a2_row2_col9, #T_362a2_row2_col10, #T_362a2_row2_col11, #T_362a2_row3_col2, #T_362a2_row3_col4, #T_362a2_row3_col6 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_362a2_row0_col2 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_362a2_row0_col3 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_362a2_row0_col4 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_362a2_row0_col6 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_362a2_row0_col8 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_362a2_row0_col9 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_362a2_row0_col10 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_362a2_row0_col11 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_362a2_row1_col0 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_362a2_row1_col1 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_362a2_row1_col2, #T_362a2_row1_col3, #T_362a2_row1_col5, #T_362a2_row1_col6, #T_362a2_row1_col7, #T_362a2_row1_col8, #T_362a2_row1_col9, #T_362a2_row1_col10, #T_362a2_row1_col11, #T_362a2_row2_col4, #T_362a2_row3_col0, #T_362a2_row3_col1, #T_362a2_row3_col8, #T_362a2_row3_col9, #T_362a2_row3_col10, #T_362a2_row3_col11 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_362a2_row1_col4 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_362a2_row2_col0 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_362a2_row2_col1 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_362a2_row2_col2 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_362a2_row2_col5 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_362a2_row2_col6 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_362a2_row2_col7 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_362a2_row3_col3 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_362a2_row3_col5 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_362a2_row3_col7 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# </style>
# <table id="T_362a2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_362a2_level0_col0" class="col_heading level0 col0" >months_as_customer</th>
#       <th id="T_362a2_level0_col1" class="col_heading level0 col1" >age</th>
#       <th id="T_362a2_level0_col2" class="col_heading level0 col2" >policy_number</th>
#       <th id="T_362a2_level0_col3" class="col_heading level0 col3" >policy_annual_premium</th>
#       <th id="T_362a2_level0_col4" class="col_heading level0 col4" >insured_zip</th>
#       <th id="T_362a2_level0_col5" class="col_heading level0 col5" >capital_gains</th>
# ...
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_8ff46_row1_col7 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_8ff46_row1_col8 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_8ff46_row1_col10 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_8ff46_row1_col11 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_8ff46_row2_col0 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_8ff46_row2_col2 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_8ff46_row2_col4 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_8ff46_row2_col5 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8ff46">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8ff46_level0_col0" class="col_heading level0 col0" >months_as_customer</th>
#       <th id="T_8ff46_level0_col1" class="col_heading level0 col1" >age</th>
#       <th id="T_8ff46_level0_col2" class="col_heading level0 col2" >policy_number</th>
#       <th id="T_8ff46_level0_col3" class="col_heading level0 col3" >policy_annual_premium</th>
#       <th id="T_8ff46_level0_col4" class="col_heading level0 col4" >insured_zip</th>
#       <th id="T_8ff46_level0_col5" class="col_heading level0 col5" >capital_gains</th>
#       <th id="T_8ff46_level0_col6" class="col_heading level0 col6" >capital_loss</th>
#       <th id="T_8ff46_level0_col7" class="col_heading level0 col7" >incident_hour_of_the_day</th>
#       <th id="T_8ff46_level0_col8" class="col_heading level0 col8" >total_claim_amount</th>
#       <th id="T_8ff46_level0_col9" class="col_heading level0 col9" >injury_claim</th>
#       <th id="T_8ff46_level0_col10" class="col_heading level0 col10" >property_claim</th>
#       <th id="T_8ff46_level0_col11" class="col_heading level0 col11" >vehicle_claim</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >property_damage</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8ff46_level0_row0" class="row_heading level0 row0" >NO</th>
#       <td id="T_8ff46_row0_col0" class="data row0 col0" >202.251773</td>
#       <td id="T_8ff46_row0_col1" class="data row0 col1" >38.886525</td>
#       <td id="T_8ff46_row0_col2" class="data row0 col2" >555157.131206</td>
#       <td id="T_8ff46_row0_col3" class="data row0 col3" >1254.641844</td>
#       <td id="T_8ff46_row0_col4" class="data row0 col4" >507594.000000</td>
#       <td id="T_8ff46_row0_col5" class="data row0 col5" >26750.354610</td>
#       <td id="T_8ff46_row0_col6" class="data row0 col6" >-27454.255319</td>
#       <td id="T_8ff46_row0_col7" class="data row0 col7" >11.202128</td>
#       <td id="T_8ff46_row0_col8" class="data row0 col8" >50789.184397</td>
#       <td id="T_8ff46_row0_col9" class="data row0 col9" >7332.056738</td>
#       <td id="T_8ff46_row0_col10" class="data row0 col10" >7169.255319</td>
#       <td id="T_8ff46_row0_col11" class="data row0 col11" >36287.872340</td>
#     </tr>
#     <tr>
#       <th id="T_8ff46_level0_row1" class="row_heading level0 row1" >UNKNOWN</th>
#       <td id="T_8ff46_row1_col0" class="data row1 col0" >206.353147</td>
#       <td id="T_8ff46_row1_col1" class="data row1 col1" >39.332168</td>
#       <td id="T_8ff46_row1_col2" class="data row1 col2" >535786.458042</td>
#       <td id="T_8ff46_row1_col3" class="data row1 col3" >1236.657343</td>
#       <td id="T_8ff46_row1_col4" class="data row1 col4" >494373.639860</td>
#       <td id="T_8ff46_row1_col5" class="data row1 col5" >22054.895105</td>
#       <td id="T_8ff46_row1_col6" class="data row1 col6" >-26354.895105</td>
#       <td id="T_8ff46_row1_col7" class="data row1 col7" >11.209790</td>
#       <td id="T_8ff46_row1_col8" class="data row1 col8" >51389.370629</td>
#       <td id="T_8ff46_row1_col9" class="data row1 col9" >7166.783217</td>
#       <td id="T_8ff46_row1_col10" class="data row1 col10" >7224.615385</td>
#       <td id="T_8ff46_row1_col11" class="data row1 col11" >36997.972028</td>
#     </tr>
#     <tr>
#       <th id="T_8ff46_level0_row2" class="row_heading level0 row2" >YES</th>
#       <td id="T_8ff46_row2_col0" class="data row2 col0" >203.228448</td>
#       <td id="T_8ff46_row2_col1" class="data row2 col1" >38.784483</td>
#       <td id="T_8ff46_row2_col2" class="data row2 col2" >542855.681034</td>
#       <td id="T_8ff46_row2_col3" class="data row2 col3" >1287.418103</td>
#       <td id="T_8ff46_row2_col4" class="data row2 col4" >505898.663793</td>
#       <td id="T_8ff46_row2_col5" class="data row2 col5" >24922.413793</td>
#       <td id="T_8ff46_row2_col6" class="data row2 col6" >-25518.534483</td>
#       <td id="T_8ff46_row2_col7" class="data row2 col7" >12.456897</td>
#       <td id="T_8ff46_row2_col8" class="data row2 col8" >54823.836207</td>
#       <td id="T_8ff46_row2_col9" class="data row2 col9" >7678.922414</td>
#       <td id="T_8ff46_row2_col10" class="data row2 col10" >7635.387931</td>
#       <td id="T_8ff46_row2_col11" class="data row2 col11" >39509.525862</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_00274_row0_col0, #T_00274_row0_col1, #T_00274_row0_col6, #T_00274_row1_col3, #T_00274_row1_col4, #T_00274_row1_col5, #T_00274_row1_col8, #T_00274_row1_col9, #T_00274_row1_col10, #T_00274_row1_col11, #T_00274_row2_col2, #T_00274_row2_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_00274_row0_col2 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_00274_row0_col3, #T_00274_row0_col4, #T_00274_row0_col8, #T_00274_row0_col9, #T_00274_row0_col10, #T_00274_row0_col11, #T_00274_row1_col0, #T_00274_row1_col1, #T_00274_row1_col2, #T_00274_row1_col7, #T_00274_row2_col5, #T_00274_row2_col6 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_00274_row0_col5 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_00274_row0_col7 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_00274_row1_col6 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_00274_row2_col0 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_00274_row2_col1 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_00274_row2_col3 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_00274_row2_col4 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_00274_row2_col8 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_00274_row2_col9 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_00274_row2_col10 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_00274_row2_col11 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_00274">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00274_level0_col0" class="col_heading level0 col0" >months_as_customer</th>
#       <th id="T_00274_level0_col1" class="col_heading level0 col1" >age</th>
#       <th id="T_00274_level0_col2" class="col_heading level0 col2" >policy_number</th>
#       <th id="T_00274_level0_col3" class="col_heading level0 col3" >policy_annual_premium</th>
#       <th id="T_00274_level0_col4" class="col_heading level0 col4" >insured_zip</th>
#       <th id="T_00274_level0_col5" class="col_heading level0 col5" >capital_gains</th>
#       <th id="T_00274_level0_col6" class="col_heading level0 col6" >capital_loss</th>
#       <th id="T_00274_level0_col7" class="col_heading level0 col7" >incident_hour_of_the_day</th>
#       <th id="T_00274_level0_col8" class="col_heading level0 col8" >total_claim_amount</th>
#       <th id="T_00274_level0_col9" class="col_heading level0 col9" >injury_claim</th>
#       <th id="T_00274_level0_col10" class="col_heading level0 col10" >property_claim</th>
#       <th id="T_00274_level0_col11" class="col_heading level0 col11" >vehicle_claim</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >police_report_available</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00274_level0_row0" class="row_heading level0 row0" >NO</th>
#       <td id="T_00274_row0_col0" class="data row0 col0" >210.035971</td>
#       <td id="T_00274_row0_col1" class="data row0 col1" >39.392086</td>
#       <td id="T_00274_row0_col2" class="data row0 col2" >538538.967626</td>
#       <td id="T_00274_row0_col3" class="data row0 col3" >1246.226619</td>
#       <td id="T_00274_row0_col4" class="data row0 col4" >498886.280576</td>
#       <td id="T_00274_row0_col5" class="data row0 col5" >24333.453237</td>
#       <td id="T_00274_row0_col6" class="data row0 col6" >-25113.309353</td>
#       <td id="T_00274_row0_col7" class="data row0 col7" >11.406475</td>
#       <td id="T_00274_row0_col8" class="data row0 col8" >49802.266187</td>
#       <td id="T_00274_row0_col9" class="data row0 col9" >6921.582734</td>
#       <td id="T_00274_row0_col10" class="data row0 col10" >7058.129496</td>
#       <td id="T_00274_row0_col11" class="data row0 col11" >35822.553957</td>
#     </tr>
#     <tr>
#       <th id="T_00274_level0_row1" class="row_heading level0 row1" >UNKNOWN</th>
#       <td id="T_00274_row1_col0" class="data row1 col0" >199.488806</td>
#       <td id="T_00274_row1_col1" class="data row1 col1" >38.750000</td>
#       <td id="T_00274_row1_col2" class="data row1 col2" >532770.376866</td>
#       <td id="T_00274_row1_col3" class="data row1 col3" >1265.477612</td>
#       <td id="T_00274_row1_col4" class="data row1 col4" >506396.839552</td>
#       <td id="T_00274_row1_col5" class="data row1 col5" >25865.671642</td>
#       <td id="T_00274_row1_col6" class="data row1 col6" >-25607.835821</td>
#       <td id="T_00274_row1_col7" class="data row1 col7" >11.186567</td>
#       <td id="T_00274_row1_col8" class="data row1 col8" >54095.074627</td>
#       <td id="T_00274_row1_col9" class="data row1 col9" >7689.514925</td>
#       <td id="T_00274_row1_col10" class="data row1 col10" >7577.947761</td>
#       <td id="T_00274_row1_col11" class="data row1 col11" >38827.611940</td>
#     </tr>
#     <tr>
#       <th id="T_00274_level0_row2" class="row_heading level0 row2" >YES</th>
#       <td id="T_00274_row2_col0" class="data row2 col0" >202.157480</td>
#       <td id="T_00274_row2_col1" class="data row2 col1" >38.885827</td>
#       <td id="T_00274_row2_col2" class="data row2 col2" >563919.141732</td>
#       <td id="T_00274_row2_col3" class="data row2 col3" >1262.106299</td>
#       <td id="T_00274_row2_col4" class="data row2 col4" >501953.228346</td>
#       <td id="T_00274_row2_col5" class="data row2 col5" >23372.440945</td>
#       <td id="T_00274_row2_col6" class="data row2 col6" >-28958.661417</td>
#       <td id="T_00274_row2_col7" class="data row2 col7" >12.149606</td>
#       <td id="T_00274_row2_col8" class="data row2 col8" >52742.244094</td>
#       <td id="T_00274_row2_col9" class="data row2 col9" >7534.881890</td>
#       <td id="T_00274_row2_col10" class="data row2 col10" >7347.755906</td>
#       <td id="T_00274_row2_col11" class="data row2 col11" >37859.606299</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_794d3_row0_col0, #T_794d3_row0_col1, #T_794d3_row0_col4, #T_794d3_row0_col7, #T_794d3_row0_col8, #T_794d3_row0_col9, #T_794d3_row0_col10, #T_794d3_row0_col11, #T_794d3_row1_col2, #T_794d3_row1_col3, #T_794d3_row1_col5, #T_794d3_row1_col6 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_794d3_row0_col2, #T_794d3_row0_col3, #T_794d3_row0_col5, #T_794d3_row0_col6, #T_794d3_row1_col0, #T_794d3_row1_col1, #T_794d3_row1_col4, #T_794d3_row1_col7, #T_794d3_row1_col8, #T_794d3_row1_col9, #T_794d3_row1_col10, #T_794d3_row1_col11 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_794d3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_794d3_level0_col0" class="col_heading level0 col0" >months_as_customer</th>
#       <th id="T_794d3_level0_col1" class="col_heading level0 col1" >age</th>
#       <th id="T_794d3_level0_col2" class="col_heading level0 col2" >policy_number</th>
#       <th id="T_794d3_level0_col3" class="col_heading level0 col3" >policy_annual_premium</th>
#       <th id="T_794d3_level0_col4" class="col_heading level0 col4" >insured_zip</th>
#       <th id="T_794d3_level0_col5" class="col_heading level0 col5" >capital_gains</th>
#       <th id="T_794d3_level0_col6" class="col_heading level0 col6" >capital_loss</th>
#       <th id="T_794d3_level0_col7" class="col_heading level0 col7" >incident_hour_of_the_day</th>
#       <th id="T_794d3_level0_col8" class="col_heading level0 col8" >total_claim_amount</th>
#       <th id="T_794d3_level0_col9" class="col_heading level0 col9" >injury_claim</th>
#       <th id="T_794d3_level0_col10" class="col_heading level0 col10" >property_claim</th>
#       <th id="T_794d3_level0_col11" class="col_heading level0 col11" >vehicle_claim</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >fraud_reported</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_794d3_level0_row0" class="row_heading level0 row0" >N</th>
#       <td id="T_794d3_row0_col0" class="data row0 col0" >202.604651</td>
#       <td id="T_794d3_row0_col1" class="data row0 col1" >38.936877</td>
#       <td id="T_794d3_row0_col2" class="data row0 col2" >550479.579734</td>
#       <td id="T_794d3_row0_col3" class="data row0 col3" >1258.689369</td>
#       <td id="T_794d3_row0_col4" class="data row0 col4" >501545.184385</td>
#       <td id="T_794d3_row0_col5" class="data row0 col5" >24822.093023</td>
#       <td id="T_794d3_row0_col6" class="data row0 col6" >-26235.215947</td>
#       <td id="T_794d3_row0_col7" class="data row0 col7" >11.443522</td>
#       <td id="T_794d3_row0_col8" class="data row0 col8" >49572.906977</td>
#       <td id="T_794d3_row0_col9" class="data row0 col9" >7102.923588</td>
#       <td id="T_794d3_row0_col10" class="data row0 col10" >6910.099668</td>
#       <td id="T_794d3_row0_col11" class="data row0 col11" >35559.883721</td>
#     </tr>
#     <tr>
#       <th id="T_794d3_level0_row1" class="row_heading level0 row1" >Y</th>
#       <td id="T_794d3_row1_col0" class="data row1 col0" >208.247475</td>
#       <td id="T_794d3_row1_col1" class="data row1 col1" >39.257576</td>
#       <td id="T_794d3_row1_col2" class="data row1 col2" >526985.095960</td>
#       <td id="T_794d3_row1_col3" class="data row1 col3" >1254.762626</td>
#       <td id="T_794d3_row1_col4" class="data row1 col4" >504902.313131</td>
#       <td id="T_794d3_row1_col5" class="data row1 col5" >23688.888889</td>
#       <td id="T_794d3_row1_col6" class="data row1 col6" >-27304.545455</td>
#       <td id="T_794d3_row1_col7" class="data row1 col7" >11.949495</td>
#       <td id="T_794d3_row1_col8" class="data row1 col8" >60081.565657</td>
#       <td id="T_794d3_row1_col9" class="data row1 col9" >8196.414141</td>
#       <td id="T_794d3_row1_col10" class="data row1 col10" >8583.333333</td>
#       <td id="T_794d3_row1_col11" class="data row1 col11" >43301.818182</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## <a id='toc2_9_'></a>[<b>7. Heatmap Correlation</b>](#toc0_)

# %% [markdown]
# <center>
# <img src='https://miro.medium.com/v2/resize:fit:640/1*hbWteVlb_CzHa5xB4KFpaQ.gif'>
# </center>
#
# A correlation matrix is a table used to summarize the associations between numeric features. The same features are shown in the rows and columns, and each cell holds the correlation coefficient of two features
#
# What to look out for:
# - Strong relationship between numeric features, drop these features to reduce **redundance (collinearity)** in data.
# - **Collinearity** is the state where two variables are highly correlated and contain similar information about the **variance within a given dataset.**

# %%
train_corr = train_set.copy()

train_corr.fraud_reported = train_corr.fraud_reported.map(dict(Y=1, N=0))

# -- Create Figure -- #
fig, ax = plt.subplots(figsize=(10,7))

# --- Create Correlation --- #
corr = train_corr[train_corr.select_dtypes(exclude='object').columns].corr()

# --- Create Mask --- #
mask = np.triu(np.ones_like(corr, dtype=bool))

# --- Cretea heatmap --- #
sns.heatmap(corr, annot=True, mask=mask, cmap='Blues', linewidths=0.1, cbar=False, annot_kws={"size":7})

# --- Figuration Setting --- #
yticks, ylabels = plt.yticks()
xticks, xlabels = plt.xticks()
ax.set_xticklabels(xlabels, size=8, fontfamily='serif')
ax.set_yticklabels(ylabels, size=8, fontfamily='serif')
plt.suptitle('Correlation Map of Numerical Variables', fontweight='heavy', x=0.327, y=0.96, ha='left', fontsize=13, fontfamily='serif')
plt.title('Some variables have significant correlations with other variables (> 0.8).\n', fontsize=10, x=0.16, y=0.92, fontfamily='serif', loc='left')
plt.tight_layout(rect=[0, 0.04, 1, 1.01])
